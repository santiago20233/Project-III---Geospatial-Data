# %%
from pymongo import MongoClient
import pandas as pd
import time
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import geopandas as gpd
from dotenv import load_dotenv
import os
import requests
import numpy as np
from src import get_offices_location

# %%
client = MongoClient("localhost:27017")
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = client["ironhack"]
c = db.get_collection("companies")

# %%
tech_companies = db.companies.aggregate([
    {
        "$unwind": "$funding_rounds"
    },
    {
        "$group": {
            "_id": "$_id",
            "name": {
                "$first": "$name"
            },
            "raised_amount": {
                "$sum": "$funding_rounds.raised_amount"
            },
            "offices": {
                "$first": "$offices"
            },
            "category_code": {
                "$first": "$category_code"
            }
        }
    },
    {
        "$match": {
            "raised_amount": {
                "$gte": 1000000
            },
            "category_code": {
                "$in": [
                    "analytics",
                    "biotech",
                    "cleantech",
                    "ecommerce",
                    "games_video",
                    "hardware",
                    "messaging",
                    "mobile",
                    "nanotech",
                    "network_hosting",
                    "search",
                    "semiconductor",
                    "social",
                    "software",
                    "transportation",
                    "travel",
                    "web"
                ]
            }
        }
    },
    {
        "$project": {
            "_id": 0,
            "name": 1,
            "raised_amount": 1,
            "offices": 1,
            "category_code": 1
        }
    }
])

# %%
tech_companies_list = list(tech_companies)

# %%
design_companies = db.companies.aggregate([
    {
        "$match": {
            "category_code": {
                "$in": [
                    "advertising",
                    "design",
                    "fashion",
                    "photo_video"
                ]
            }
        }
    },
    {
        "$project": {
            "_id": 0,
            "name": 1,
            "offices": 1
        }
    }
])

# %%
design_companies_list = list (design_companies)

# %%
def get_offices_location (data):
    nested_data = []
    for item in data:
        name = item['name']
        for office in item['offices']:
            nested_data.append({
                'name': name,
                'office description': office['description'],
                'office latitude': office['latitude'],
                'office longitude': office['longitude']
            })
    df = pd.DataFrame(nested_data)
    return df

# %%
design_data = get_offices_location(design_companies_list)

# %%
tech_data = get_offices_location(tech_companies_list)

# %%
design_data = design_data.dropna(subset=["office latitude", "office longitude"], how="all")
tech_data = tech_data.dropna(subset=["office latitude", "office longitude"], how="all")

# %%
world_map = Map(location = [0, 0], zoom_start = 2)

# %%
tech_group = folium.FeatureGroup(name=f"Tech ({tech_data.shape[0]})")
design_group = folium.FeatureGroup(name = f"Design ({design_data.shape[0]})")
HeatMap(data = tech_data[["office latitude", "office longitude"]]).add_to(tech_group)
HeatMap(data = design_data[["office latitude", "office longitude"]]).add_to(design_group)
tech_group.add_to(world_map)
design_group.add_to(world_map)
folium.LayerControl(collapsed=False, position="topleft").add_to(world_map)
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_447bd03e74dab9577b833e27edaee4bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_447bd03e74dab9577b833e27edaee4bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_447bd03e74dab9577b833e27edaee4bd = L.map(
#                 &quot;map_447bd03e74dab9577b833e27edaee4bd&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb10f3a4d9341804f0ba95712b4963bb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_447bd03e74dab9577b833e27edaee4bd);
#
#
#             var feature_group_7cd98c4fb89c2ba60e9c9304ea54fd9a = L.featureGroup(
#                 {}
#             ).addTo(map_447bd03e74dab9577b833e27edaee4bd);
#
#
#             var heat_map_3d94f94c862284e585800f8ac1a3b2f7 = L.heatLayer(
#                 [[17.08881, -96.76492], [48.122962, 11.5485907], [26.1875706, -80.1912988], [37.385225, -121.991912], [47.5989681, -122.3329036], [34.1549426, -118.6545471], [26.4074809, -80.1169895], [44.940367, 4.8665775], [37.785271, -122.397582], [37.390501, -122.081151], [34.186206, -118.50391], [37.41924, -122.208414], [27.6476577, -80.3821092], [34.046788, -84.300914], [29.6982817, -95.3500171], [37.09024, -95.712891], [37.334738, -121.891516], [42.355077, -71.056928], [37.524851, -122.257185], [26.170422, -80.150794], [41.8879192, -87.6354206], [52.3640933, 4.8919457], [37.787683, -122.410943], [51.500152, -0.126236], [37.383844, -121.918319], [39.767289, -86.139793], [51.518107, -0.134078], [42.36867, -71.150248], [37.559287, -122.302262], [47.682233, -122.135521], [37.767575, -122.411157], [52.6638571, -8.6267726], [51.5001524, -0.1262362], [49.2549899, -122.9170962], [48.856667, 2.350987], [40.4653401, -86.9316959], [37.4192309, -122.0887097], [47.5827406, -122.1353561], [55.6739617, 12.5605372], [33.817752, -84.120458], [54.2706906, -8.4806856], [37.393536, -122.076747], [32.948733, -96.827495], [37.661002, -121.897829], [42.334732, -71.592595], [34.01052, -118.495981], [52.195668, 0.130647], [34.7465, -92.2894], [46.8149807, -71.2722665], [37.386665, -122.084171], [37.793473, -122.402667], [40.530724, -3.632687], [39.97764, -105.13114], [42.040851, -87.750643], [37.536402, -122.325129], [40.74406, -74.004592], [49.1739359, -123.071751], [48.856667, 2.350987], [38.9579071, -77.3577568], [34.1030032, -118.4104684], [47.604242, -122.334448], [51.500152, -0.126236], [37.09024, -95.712891], [40.752672, -73.97593], [37.418491, -122.08744], [40.4474363, -3.6714915], [41.0016627, -5.6937933], [38.2743225, -122.6670066], [37.789488, -122.397593], [43.6878093, -79.3958388], [42.356931, -71.053991], [33.982431, -118.426707], [45.533544, -122.688602], [34.043948, -118.468204], [37.384239, -122.012475], [30.271393, -97.748623], [34.031178, -118.463841], [37.7800539, -122.3912492], [39.5688576, -105.1236849], [39.1729181, -76.6447438], [45.5251, -122.8097], [50.8726449, 4.276811], [40.4290508, -79.9707345], [40.755978, -73.990396], [42.559391, -71.432373], [37.377972, -122.033361], [53.3401356, -6.2962414], [51.500152, -0.126236], [51.5003204, -0.0178689], [40.0173513, -105.2773493], [40.4161835, -3.6988729], [37.776878, -122.400934], [37.386774, -121.987661], [58.3820542, 26.731054], [37.411009, -122.006265], [37.519102, -122.264348], [51.5499708, -0.1815999], [28.5821195, 77.3266991], [37.377787, -122.029217], [37.400751, -122.031591], [38.992699, -76.93873], [33.983543, -118.432526], [37.553743, -122.300246], [43.648786, -79.3777473], [42.364367, -71.078978], [52.36702, 4.896468], [37.488336, -122.217964], [42.350571, -71.076869], [40.74034, -74.00721], [47.6234781, -122.3343544], [34.045845, -118.237811], [39.360128, -84.308653], [37.279485, -121.94356], [47.599925, -122.334264], [31.046051, 34.851612], [37.42105, -121.893859], [37.388529, -121.967199], [33.129172, -117.286973], [59.939039, 30.315785], [42.3514855, -71.0572879], [42.007496, -71.5022314], [30.161661, -95.471256], [39.7672093, -86.1580785], [37.09024, -95.712891], [37.3802792, -121.9703344], [37.563585, -122.324621], [42.9959408, -71.4634803], [41.881978, -87.630125], [51.865488, -2.235187], [39.5604863, -104.8656251], [37.395335, -122.102339], [37.523194, -122.259179], [37.566042, -122.322954], [37.789268, -122.395184], [47.600818, -122.334117], [30.306591, -97.826727], [48.8952712, 2.4476331], [29.4748, -81.1274], [37.09024, -95.712891], [37.386417, -121.92917], [37.803847, -122.402468], [37.3955775, -122.0833286], [26.820375, -80.058401], [39.74893, -104.99342], [4

# %%
def load_cities(city_names):
    cities = {}
    for city_name in city_names:
        city_geo = gpd.read_file(f"Geojsons/{city_name}.geojson")
        cities[city_name.title()] = city_geo.geometry[0]
    return cities

def add_city_name(df, cities):
    city_names = []
    for _, row in df.iterrows():
        lat, lon = row['office latitude'], row['office longitude']
        point = gpd.points_from_xy([lon], [lat])
        for city_name, city_geometry in cities.items():
            if point.within(city_geometry)[0]:
                city_names.append(city_name)
                break
        else:
            city_names.append(None)
    df['city'] = city_names
    return df

# %%
city_names = ["london"]
cities = load_cities(city_names)
cities
# Out:
# {'London': <shapely.geometry.polygon.Polygon at 0x7ff4592cd9a0>}

# %%
tech_data = add_city_name(tech_data, cities)
tech_data["type"] = "tech"
tech_data
# Out:
#                      name     office description  office latitude  \
# 0               Sportingo                   None        17.088810
# 1                 Conject           Headquarters        48.122962
# 2          Veraz Networks                               26.187571
# 3                   4Home                               37.385225
# 4         Local Marketers                               47.598968
# ...                   ...                    ...              ...
# 3762  Winbox Technologies  Office Furtwagen (HQ)        48.050514
# 3763              PodTech                   None        37.408256
# 3765         mPay Gateway                               44.989830
# 3766          The Society           Headquarters        39.658017
# 3767   Everyday Solutions                     HQ        42.462355
#
#       office longitude  city  type
# 0           -96.764920  None  tech
# 1            11.548591  None  tech
# 2           -80.191299  None  tech
# 3          -121.991912  None  tech
# 4          -122.332904  None  tech
# ...                ...   ...   ...
# 3762          8.205405  None  tech
# 3763       -122.154176  None  tech
# 3765        -93.274300  None  tech
# 3766       -105.084475  None  tech
# 3767        -71.379736  None  tech
#
# [2489 rows x 6 columns]

# %%
design_data = add_city_name(design_data, cities)
design_data["type"] = "design"
design_data
# Out:
#                      name  office description  office latitude  \
# 0              Technorati                            37.779558
# 1                 AddThis       HQ - Virginia        38.926172
# 2                 AddThis     New York Office        40.724604
# 3                 AddThis  Los Angeles Office        34.026302
# 6                 AddThis     Michigan Office        42.557958
# ...                   ...                 ...              ...
# 1084           Media Whiz                  HQ        26.117613
# 1085           Relevantis                            47.676786
# 1088       United On-Line        Headquarters        38.008825
# 1089  MarketLine Research                            44.982264
# 1092             InstantQ                            37.369195
#
#       office longitude  city    type
# 0          -122.393041  None  design
# 1           -77.245195  None  design
# 2           -73.996876  None  design
# 3          -118.380954  None  design
# 6           -83.167884  None  design
# ...                ...   ...     ...
# 1084        -80.263339  None  design
# 1085       -122.204918  None  design
# 1088         23.759331  None  design
# 1089        -93.235614  None  design
# 1092       -122.036849  None  design
#
# [708 rows x 6 columns]

# %%
full_city_data = pd.concat([tech_data, design_data], axis=0)
final_city = full_city_data.groupby(['city', 'type'])['name'].agg('count').reset_index()
final_city
# Out:
#      city    type  name
# 0  London  design    31
# 1  London    tech    52

# %%
final_city = full_city_data[full_city_data['city'].isin(['London'])]
final_city
# Out:
#                    name office description  office latitude  office longitude  \
# 29               eBuddy   Singapore office        51.500152         -0.126236
# 35               Telnic        Head Office        51.518107         -0.134078
# 41              WorldTV      London Office        51.500152         -0.126236
# 84                 WAYN               None        51.500152         -0.126236
# 132            Seatwave                           51.500152         -0.126236
# ...                 ...                ...              ...               ...
# 1020  Real Time Content      London Office        51.520936         -0.142409
# 1036       Adeye Mobile    Adeye London HQ        51.515129         -0.129771
# 1042       AgreeYourFee                           51.500152         -0.126236
# 1063        DoTradeEasy    DoTradeEasy Ltd        51.527057         -0.104377
# 1065              Struq          London HQ        51.515202         -0.136686
#
#         city    type
# 29    London    tech
# 35    London    tech
# 41    London    tech
# 84    London    tech
# 132   London    tech
# ...      ...     ...
# 1020  London  design
# 1036  London  design
# 1042  London  design
# 1063  London  design
# 1065  London  design
#
# [83 rows x 6 columns]

# %%
london_map = Map(location = [51, 0], zoom_start = 4)
tech_group = folium.FeatureGroup(name=f"Tech ({final_city[final_city['type'] == 'tech'].shape[0]})")
design_group = folium.FeatureGroup(name = f"Design ({final_city[final_city['type'] == 'design'].shape[0]})")


for index, row in final_city.iterrows():
    
    # 1. Marker: template
    city = {
        "location": [row["office latitude"], row["office longitude"]],
        "tooltip": row["name"]
    }
        
    # 2. icon: based on the type of company
    
    if row["type"] == "tech":
        icon = Icon (
            color = "blue",
            prefix="fa",
            icon="briefcase",
        )
    else:
        icon = Icon(
            color = "green",
            prefix="fa",
            icon="shirt"
        )
        
    
    # 3. Marker 
    new_marker = Marker (**city, icon = icon)
    
    # 4. -> to map
    if row["type"] == "tech":
        new_marker.add_to(tech_group)
    else:
        new_marker.add_to(design_group)
    

tech_group.add_to(london_map)
design_group.add_to(london_map)
folium.LayerControl(collapsed=False, position="topleft").add_to(london_map)
london_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80024e1cdfd618d92eb0941245fb1207 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80024e1cdfd618d92eb0941245fb1207&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80024e1cdfd618d92eb0941245fb1207 = L.map(
#                 &quot;map_80024e1cdfd618d92eb0941245fb1207&quot;,
#                 {
#                     center: [51.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be7d8fe63279f9cd173172abfb5f9c17 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_80024e1cdfd618d92eb0941245fb1207);
#
#
#             var feature_group_2a517af7588f02e8ee3074cc8c260620 = L.featureGroup(
#                 {}
#             ).addTo(map_80024e1cdfd618d92eb0941245fb1207);
#
#
#             var marker_645535e3f5a8aa300bc28300afb5842e = L.marker(
#                 [51.500152, -0.126236],
#                 {}
#             ).addTo(feature_group_2a517af7588f02e8ee3074cc8c260620);
#
#
#             var icon_32baceeeb2679bec44a33626f43ae858 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_645535e3f5a8aa300bc28300afb5842e.setIcon(icon_32baceeeb2679bec44a33626f43ae858);
#
#
#             marker_645535e3f5a8aa300bc28300afb5842e.bindTooltip(
#                 `&lt;div&gt;
#                      eBuddy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3176664e49b011519ff6e83aa6c2a25e = L.marker(
#                 [51.518107, -0.134078],
#                 {}
#             ).addTo(feature_group_2a517af7588f02e8ee3074cc8c260620);
#
#
#             var icon_bee0247a95ad90e6356baee2bc02c11b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3176664e49b011519ff6e83aa6c2a25e.setIcon(icon_bee0247a95ad90e6356baee2bc02c11b);
#
#
#             marker_3176664e49b011519ff6e83aa6c2a25e.bindTooltip(
#                 `&lt;div&gt;
#                      Telnic
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5b7d5a521c0e35b30a42057990f9fa75 = L.marker(
#                 [51.5001524, -0.1262362],
#                 {}
#             ).addTo(feature_group_2a517af7588f02e8ee3074cc8c260620);
#
#
#             var icon_12db126c141968677e47bafcacb255ce = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5b7d5a521c0e35b30a42057990f9fa75.setIcon(icon_12db126c141968677e47bafcacb255ce);
#
#
#             marker_5b7d5a521c0e35b30a42057990f9fa75.bindTooltip(
#                 `&lt;div&gt;
#                      WorldTV
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aaa8b23d5055168e47b52f35c1a9fcba = L.marker(
#                 [51.500152, -0.126236],
#                 {}
#             ).addTo(feature_group_2a517af7588f02e8ee3074cc8c260620);
#
#
#             var icon_0f84f99dc04605d2b6801d19cc2dbf9b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_aaa8b23d5055168e47b52f35c1a9fcba.setIcon(icon_0f84f99dc04605d2b6801d19cc2dbf9b);
#
#
#             marker_aaa8b23d5055168e47b52f35c1a9fcba.bindTooltip(
#                 `&lt;div&gt;
#                      WAYN
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ac8e6a8e16457ef2ea850609e4bd43b0 = L.marker(
#                 [51.500152, -0.126236],
#                 {}
#             ).addTo(feature_group_2a517af7588f02e8ee3074cc8c260620);
#
#
#             var icon_fcdd484720298fa89bf315e17a7c99d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot

# %%
def centroid_coordinates(df):
    centroid_lat = df["office latitude"].sum() / len(df)
    centroid_lon = df["office longitude"].sum() / len(df)
    return [round(centroid_lat, 4), round(centroid_lon, 4)]

london_tech = centroid_coordinates(final_city[(final_city["city"] == 'London') & (final_city["type"] == 'tech')])
london_design = centroid_coordinates(final_city[(final_city["city"] == 'London') & (final_city["type"] == 'design')])

# %%
def add_marker (name, color, icon_, coordinates, map):
    icon1 = Icon(
    color = color,
    opacity = 0.1,
    prefix = "fa", #font-awesome
    icon = icon_,
    icon_color = "white"
    )   
    marker_ = Marker(
    location = coordinates,
    tooltip = name,
    icon = icon1
    )
    marker_.add_to(map)
    return map

# %%
add_marker("tech_middle","red","rocket",london_tech,london_map)
add_marker("design_middle","red","rocket",london_design,london_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80024e1cdfd618d92eb0941245fb1207 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80024e1cdfd618d92eb0941245fb1207&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80024e1cdfd618d92eb0941245fb1207 = L.map(
#                 &quot;map_80024e1cdfd618d92eb0941245fb1207&quot;,
#                 {
#                     center: [51.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be7d8fe63279f9cd173172abfb5f9c17 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_80024e1cdfd618d92eb0941245fb1207);
#
#
#             var feature_group_2a517af7588f02e8ee3074cc8c260620 = L.featureGroup(
#                 {}
#             ).addTo(map_80024e1cdfd618d92eb0941245fb1207);
#
#
#             var marker_645535e3f5a8aa300bc28300afb5842e = L.marker(
#                 [51.500152, -0.126236],
#                 {}
#             ).addTo(feature_group_2a517af7588f02e8ee3074cc8c260620);
#
#
#             var icon_32baceeeb2679bec44a33626f43ae858 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_645535e3f5a8aa300bc28300afb5842e.setIcon(icon_32baceeeb2679bec44a33626f43ae858);
#
#
#             marker_645535e3f5a8aa300bc28300afb5842e.bindTooltip(
#                 `&lt;div&gt;
#                      eBuddy
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3176664e49b011519ff6e83aa6c2a25e = L.marker(
#                 [51.518107, -0.134078],
#                 {}
#             ).addTo(feature_group_2a517af7588f02e8ee3074cc8c260620);
#
#
#             var icon_bee0247a95ad90e6356baee2bc02c11b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3176664e49b011519ff6e83aa6c2a25e.setIcon(icon_bee0247a95ad90e6356baee2bc02c11b);
#
#
#             marker_3176664e49b011519ff6e83aa6c2a25e.bindTooltip(
#                 `&lt;div&gt;
#                      Telnic
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5b7d5a521c0e35b30a42057990f9fa75 = L.marker(
#                 [51.5001524, -0.1262362],
#                 {}
#             ).addTo(feature_group_2a517af7588f02e8ee3074cc8c260620);
#
#
#             var icon_12db126c141968677e47bafcacb255ce = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5b7d5a521c0e35b30a42057990f9fa75.setIcon(icon_12db126c141968677e47bafcacb255ce);
#
#
#             marker_5b7d5a521c0e35b30a42057990f9fa75.bindTooltip(
#                 `&lt;div&gt;
#                      WorldTV
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aaa8b23d5055168e47b52f35c1a9fcba = L.marker(
#                 [51.500152, -0.126236],
#                 {}
#             ).addTo(feature_group_2a517af7588f02e8ee3074cc8c260620);
#
#
#             var icon_0f84f99dc04605d2b6801d19cc2dbf9b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_aaa8b23d5055168e47b52f35c1a9fcba.setIcon(icon_0f84f99dc04605d2b6801d19cc2dbf9b);
#
#
#             marker_aaa8b23d5055168e47b52f35c1a9fcba.bindTooltip(
#                 `&lt;div&gt;
#                      WAYN
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ac8e6a8e16457ef2ea850609e4bd43b0 = L.marker(
#                 [51.500152, -0.126236],
#                 {}
#             ).addTo(feature_group_2a517af7588f02e8ee3074cc8c260620);
#
#
#             var icon_fcdd484720298fa89bf315e17a7c99d1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot

# %%
def mean_coordinates_raw (list_):
    x = 0
    y = 0
    for i in list_:
        x +=i[0]
        y +=i[1]
    x = x/len(list_)
    y = y/len(list_)

    return [round(x,4), round(y,4)]

office_location = mean_coordinates_raw([london_tech,london_design])
office_location
# Out:
# [51.5134, -0.119]

# %%
load_dotenv()
# Out:
# True

# %%
fsq_tok = os.getenv("token")

# %%
def process_4sq_data(data):
    rows = []
    for result in data['results']:
        row = {
            'name': result['name'],
            'distance': result['distance'],
            'latitude': result['geocodes']['main']['latitude'],
            'longitude': result['geocodes']['main']['longitude'],
            'category_id': result['categories'][0]['id'],
            'category_name': result['categories'][0]['name']
        }
        rows.append(row)
    df = pd.DataFrame(rows).sort_values(by='distance', ascending=True)
    return df

# %%
url = "https://api.foursquare.com/v3/places/search?ll=51.5134%2C-0.1191&radius=50000&categories=19040"

headers = {
    "accept": "application/json",
    "Authorization": fsq_tok
}

response = requests.get(url, headers=headers)

airports_raw = response.json()
airports = process_4sq_data(airports_raw)
airports
# Out:
#                             name  distance   latitude  longitude  category_id  \
# 1      London City Airport (LCY)     11710  51.504029   0.049552        19040
# 0  London Heathrow Airport (LHR)     24005  51.470584  -0.454958        19040
# 2   London Gatwick Airport (LGW)     39601  51.156710  -0.163651        19040
#
#            category_name
# 1  International Airport
# 0  International Airport
# 2  International Airport

# %%
url = "https://api.foursquare.com/v3/places/search?ll=51.5134%2C-0.1191&radius=2000&categories=12056%2C12057&sort=DISTANCE&limit=30"

headers = {
    "accept": "application/json",
    "Authorization": fsq_tok
}

response_schools = requests.get(url, headers=headers)

schools_raw = response_schools.json()
schools = process_4sq_data(schools_raw)
schools
# Out:
#                                                  name  distance   latitude  \
# 0              St Clement Danes C of E Primary School        53  51.513551
# 1                       St Josephs R C Primary School       361  51.516129
# 2                         Kensington Aldridge Academy       608  51.508648
# 3                               Erp Solution Advisors       852  51.517171
# 4                            St Albans Primary School       960  51.520223
# 5   St George the Martyr Church of England Primary...       977  51.522017
# 6                            Rubadubs Nursery Limited       984  51.518732
# 7                                              Jivjav      1021  51.507478
# 8                              London Nautical School      1057  51.506494
# 9                   Soho Parish C of E Primary School      1059  51.511711
# 10                            Henry George Foundation      1127  51.517018
# 11                  Christopher Hatton Primary School      1150  51.522691
# 12                           Oasis Academy South Bank      1154  51.498369
# 13                           Mobile English Education      1315  51.524193
# 14                               Tomorrow's Achievers      1324  51.524899
# 15                                  Elliot Foundation      1336  51.525345
# 16                              Oasis Academy Johanna      1413  51.501621
# 17                              City of London School      1448  51.511060
# 18                             Johanna Primary School      1463  51.500915
# 19                                Home Star Childcare      1522  51.513242
# 20                    All Souls C of E Primary School      1527  51.519959
# 21                         St Paul's Cathedral School      1560  51.513723
# 22                                            So Tiny      1576  51.517976
# 23                                   Waterloo Nursery      1607  51.500266
# 24                       Kanterbury House Day Nursery      1616  51.498986
# 25                                      Argyle School      1691  51.528292
# 26                                    Little Pioneers      1693  51.499264
# 27                                  Elliot Foundation      1731  51.528019
# 28                              Argyle Primary School      1739  51.528742
# 29                                      Wey Education      1740  51.512233
#
#     longitude  category_id                 category_name
# 0   -0.119217        12058             Elementary School
# 1   -0.121953        12058             Elementary School
# 2   -0.123480        12059                   High School
# 3   -0.129837        12057  Primary and Secondary School
# 4   -0.110579        12058             Elementary School
# 5   -0.116266        12057  Primary and Secondary School
# 6   -0.107732        12056                     Preschool
# 7   -0.107800        12057  Primary and Secondary School
# 8   -0.108033        12059                   High School
# 9   -0.134438        12058             Elementary School
# 10  -0.134326        12059                   High School
# 11  -0.112192        12058             Elementary School
# 12  -0.111783        12059                   High School
# 13  -0.111278        12059                   High School
# 14  -0.124130        12059                   High School
# 15  -0.116806        12058             Elementary School
# 16  -0.111636        12058             Elementary School
# 17  -0.099303        12059                   High School
# 18  -0.111699        12058             Elementary School
# 19  -0.141109        11025            Child Care Service
# 20  -0.138584        12058             Elementary School
# 21  -0.096676        12057  Primary and Secondary School
# 22  -0.140522        12056                     Preschool
# 23  -0.109347        12056                     Preschool
# 24  -0.115985        12056                     Preschool
# 25  -0.124448        12058             Elementary School
# 26  -0.109957        11025            Child Care Service
# 27  -0.110416        12058             Elementary School
# 28  -0.124083        12058             Elementary School
# 29  -0.144195        12057  Primary and Secondary School

# %%
url = "https://api.foursquare.com/v3/places/search?ll=51.5134%2C-0.1191&radius=2000&chains=ab4c54c0-d68a-012e-5619-003048cad9da&sort=DISTANCE&limit=10"

headers = {
    "accept": "application/json",
    "Authorization": fsq_tok
}

response_starbucks = requests.get(url, headers=headers)

starbucks_raw = response_starbucks.json()
starbucks = process_4sq_data(starbucks_raw)
starbucks
# Out:
#         name  distance   latitude  longitude  category_id category_name
# 0  Starbucks       111  51.513847  -0.117479        13035   Coffee Shop
# 1  Starbucks       214  51.512244  -0.121751        13035   Coffee Shop
# 2  Starbucks       332  51.516379  -0.120061        13035   Coffee Shop
# 3  Starbucks       546  51.514722  -0.126655        13035   Coffee Shop
# 4  Starbucks       700  51.507587  -0.123026        13035   Coffee Shop
# 5  Starbucks       710  51.507480  -0.122999        13035   Coffee Shop
# 6  Starbucks       714  51.518223  -0.125809        13035   Coffee Shop
# 7  Starbucks       740  51.518523  -0.112254        13035   Coffee Shop
# 8  Starbucks       793  51.515096  -0.130274        13035   Coffee Shop
# 9  Starbucks       795  51.516658  -0.129233        13035   Coffee Shop

# %%
url = "https://api.foursquare.com/v3/places/search?ll=51.5134%2C-0.1191&radius=10000&categories=18006&sort=DISTANCE&limit=15"

headers = {
    "accept": "application/json",
    "Authorization": fsq_tok
}

response_basket = requests.get(url, headers=headers)

basket_raw = response_basket.json()
basket = process_4sq_data(basket_raw)
basket
# Out:
#                                     name  distance   latitude  longitude  \
# 0                      Basket Ball Court      1462  51.525298  -0.109598
# 1            Spa Fields Basketball Court      1504  51.525410  -0.108339
# 2                GMH Park Netball Courts      2127  51.496010  -0.106626
# 3                              The Regal      2460  51.491352  -0.114949
# 4                       Basketball Court      2632  51.501277  -0.086212
# 5                         Netball Courts      2816  51.536528  -0.137030
# 6                       Basketball Court      3397  51.531601  -0.079473
# 7        Lisson Grove - Basketball Court      3668  51.525673  -0.168182
# 8                      Basketball Courts      3707  51.487366  -0.085247
# 9      Tabard Gardens - Basketball Court      3852  51.514811  -0.174869
# 10                      Basketball Court      4643  51.525673  -0.055333
# 11       Clapham Common Basketball Court      6146  51.460019  -0.142943
# 12                      Basketball Court      7975  51.490018  -0.228093
# 13       Island Gardens Basketball Court      8002  51.488234  -0.010596
# 14  Lindsell Street Multi-Use Games Area      8547  51.473653  -0.013718
#
#     category_id     category_name
# 0         18008  Basketball Court
# 1         18008  Basketball Court
# 2         18008  Basketball Court
# 3         18008  Basketball Court
# 4         18008  Basketball Court
# 5         18008  Basketball Court
# 6         18008  Basketball Court
# 7         18008  Basketball Court
# 8         18008  Basketball Court
# 9         18008  Basketball Court
# 10        18008  Basketball Court
# 11        18008  Basketball Court
# 12        18008  Basketball Court
# 13        18008  Basketball Court
# 14        18008  Basketball Court

# %%
url = "https://api.foursquare.com/v3/places/search?ll=51.5134%2C-0.1191&radius=5000&categories=13377&sort=DISTANCE&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": fsq_tok
}

response_vegan = requests.get(url, headers=headers)

vegan_raw = response_vegan.json()
vegan = process_4sq_data(vegan_raw)
vegan
# Out:
#                           name  distance   latitude  longitude  category_id  \
# 0                        Sagar       141  51.512617  -0.120700        13072
# 1                    Farmstand       224  51.514349  -0.121845        13377
# 2                  Just Falafs       308  51.512025  -0.122983        13145
# 3               Wild Food Cafe       519  51.514521  -0.126319        13377
# 4                       Pilpel       828  51.514372  -0.107270        13144
# 5                        Vitao       914  51.516507  -0.131340        13377
# 6            Vantra Loungevity       935  51.510579  -0.132012        13377
# 7         Govinda's Restaurant       973  51.515847  -0.132749        13199
# 8            Soho Vegan Market      1021  51.512346  -0.133595        13377
# 9                         Leon      1027  51.514310  -0.103920        13145
# 10                    Mildreds      1196  51.513075  -0.136540        13377
# 11                Little India      1214  51.524143  -0.115888        13199
# 12  Hoxton Beach Falafel Stall      1364  51.519511  -0.136566        13144
# 13                    Flipside      1367  51.520001  -0.102471        13145
# 14                      Pilpel      1441  51.514984  -0.098656        13144
# 15              Stem and Glory      1516  51.518335  -0.098723        13377
# 16                         Kin      1605  51.519444  -0.140363        13035
# 17                 Neat Burger      1633  51.514627  -0.142740        13377
# 18             Cafeteria Vegan      1777  51.513179  -0.144811        13377
# 19     Diwana Bhel Poori House      1949  51.526978  -0.136515        13223
#
#                       category_name
# 0                  Asian Restaurant
# 1   Vegan and Vegetarian Restaurant
# 2              Fast Food Restaurant
# 3   Vegan and Vegetarian Restaurant
# 4                Falafel Restaurant
# 5   Vegan and Vegetarian Restaurant
# 6   Vegan and Vegetarian Restaurant
# 7                 Indian Restaurant
# 8   Vegan and Vegetarian Restaurant
# 9              Fast Food Restaurant
# 10  Vegan and Vegetarian Restaurant
# 11                Indian Restaurant
# 12               Falafel Restaurant
# 13             Fast Food Restaurant
# 14               Falafel Restaurant
# 15  Vegan and Vegetarian Restaurant
# 16                      Coffee Shop
# 17  Vegan and Vegetarian Restaurant
# 18  Vegan and Vegetarian Restaurant
# 19          South Indian Restaurant

# %%
url = "https://api.foursquare.com/v3/places/search?ll=51.5134%2C-0.1191&radius=2500&categories=11134&sort=DISTANCE&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": fsq_tok
}

response_pet = requests.get(url, headers=headers)
pet_raw = response_pet.json()
pet = process_4sq_data(pet_raw)
pet
# Out:
#                                  name  distance   latitude  longitude  \
# 0         BOW WOW London Dog Grooming       661  51.518280  -0.124584
# 1                            Marabese      1685  51.500761  -0.132576
# 2  Love Your Pets Grooming & Boutique      2288  51.533094  -0.109435
#
#    category_id         category_name
# 0        11134  Pet Grooming Service
# 1        11134  Pet Grooming Service
# 2        11134  Pet Grooming Service

# %%
url = "https://api.foursquare.com/v3/places/search?ll=51.5134%2C-0.1191&radius=1000&categories=10032"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3BsavsPN2+4+aYMMFcu7hhMBtnzwJ0a3poXWeA0zd5dg="
}

response_club= requests.get(url, headers=headers)
club_raw = response_club.json()
clubs = process_4sq_data(club_raw)
clubs
# Out:
#                    name  distance   latitude  longitude  category_id  \
# 9  The Hercules Pillars       290  51.515856  -0.120837        10032
# 5      Proud Embankment       386  51.510094  -0.117930        10032
# 8      The Yacht London       472  51.510478  -0.114309        10032
# 2   Lucky Voice Holborn       535  51.515777  -0.112002        10032
# 0             Retro Bar       562  51.509123  -0.123740        10032
# 6                Heaven       695  51.508129  -0.124161        10032
# 4                Ku Bar       745  51.511827  -0.129606        10032
# 1        Ronnie Scott's       867  51.513310  -0.131451        10032
# 3    Duke of Wellington       976  51.512307  -0.133251        10032
# 7  The Friendly Society       982  51.512363  -0.133218        10032
#
#   category_name
# 9    Night Club
# 5    Night Club
# 8    Night Club
# 2    Night Club
# 0    Night Club
# 6    Night Club
# 4    Night Club
# 1    Night Club
# 3    Night Club
# 7    Night Club

# %%
pet["group"] = "Pet Grooming"
vegan["group"] = "Vegan Food"
basket["group"] = "Basket court"
starbucks["group"] = "Starbucks"
schools["group"] = "Schools"
airports["group"] = "Airports"
clubs["group"]= "Clubs"

# %%
near_office = pd.concat([pet, vegan, basket, starbucks, schools, airports, clubs], axis=0)

# %%
near_office
# Out:
#                                   name  distance   latitude  longitude  \
# 0          BOW WOW London Dog Grooming       661  51.518280  -0.124584
# 1                             Marabese      1685  51.500761  -0.132576
# 2   Love Your Pets Grooming & Boutique      2288  51.533094  -0.109435
# 0                                Sagar       141  51.512617  -0.120700
# 1                            Farmstand       224  51.514349  -0.121845
# ..                                 ...       ...        ...        ...
# 6                               Heaven       695  51.508129  -0.124161
# 4                               Ku Bar       745  51.511827  -0.129606
# 1                       Ronnie Scott's       867  51.513310  -0.131451
# 3                   Duke of Wellington       976  51.512307  -0.133251
# 7                 The Friendly Society       982  51.512363  -0.133218
#
#     category_id                    category_name         group
# 0         11134             Pet Grooming Service  Pet Grooming
# 1         11134             Pet Grooming Service  Pet Grooming
# 2         11134             Pet Grooming Service  Pet Grooming
# 0         13072                 Asian Restaurant    Vegan Food
# 1         13377  Vegan and Vegetarian Restaurant    Vegan Food
# ..          ...                              ...           ...
# 6         10032                       Night Club         Clubs
# 4         10032                       Night Club         Clubs
# 1         10032                       Night Club         Clubs
# 3         10032                       Night Club         Clubs
# 7         10032                       Night Club         Clubs
#
# [91 rows x 7 columns]

# %%
office_nearby = Map(location = [51, 0], zoom_start = 11.4)
pet_group = folium.FeatureGroup(name=f"Pet grooming ({near_office[near_office['group'] == 'Pet Grooming'].shape[0]})")
vegan_group = folium.FeatureGroup(name = f"Vegan restaurants ({near_office[near_office['group'] == 'Vegan Food'].shape[0]})")
basket_group = folium.FeatureGroup(name = f"Basketball courts ({near_office[near_office['group'] == 'Basket court'].shape[0]})")
starbucks_group = folium.FeatureGroup(name = f"Starbucks ({near_office[near_office['group'] == 'Starbucks'].shape[0]})")
schools_group = folium.FeatureGroup(name = f"Schools ({near_office[near_office['group'] == 'Schools'].shape[0]})")
airports_group = folium.FeatureGroup(name = f"Airports ({near_office[near_office['group'] == 'Airports'].shape[0]})")
clubs_group = folium.FeatureGroup(name = f"Clubs ({near_office[near_office['group'] == 'Clubs'].shape[0]})")

# Iteration through DataFrame to create marker and add it to the corresponding group.
for index, row in near_office.iterrows():
    
    # 1. Marker: creates the marker in the office location and adds the name to it.
    city = {
        "location": [row["latitude"], row["longitude"]],
        "tooltip": row["name"]
    }
        
    # 2. Add the icon: based on the type of venue
    
    if row["group"] == "Pet Grooming":
        icon = Icon (
            color = "blue",
            prefix="fa",
            icon="dog"
        )
    elif row["group"] == "Vegan Food":
        icon = Icon (
            color = "lightgreen",
            prefix="fa",
            icon="leaf"
        )
    elif row["group"] == "Basket court":
        icon = Icon (
            color = "orange",
            prefix="fa",
            icon="basketball"
        )
    elif row["group"] == "Starbucks":
        icon = Icon (
            color = "green",
            prefix="fa",
            icon="coffee"
        )
    elif row["group"] == "Schools":
        icon = Icon (
            color = "purple",
            prefix="fa",
            icon="school"
        )
    elif row["group"] == "Clubs":
        icon = Icon (
            color = "darkblue",
            prefix="fa",
            icon="martini-glass"
        )
    else:
        icon = Icon(
            color = "cadetblue",
            prefix="fa",
            icon="plane"
        )
        
    
    # 3. Creates the map Marker
    new_marker = Marker (**city, icon = icon)
    
    # 4. Adds the marker to the corresponding group
    if row["group"] == "Pet Grooming":
        new_marker.add_to(pet_group)
    elif row["group"] == "Vegan Food":
        new_marker.add_to(vegan_group)
    elif row["group"] == "Basket court":
        new_marker.add_to(basket_group)
    elif row["group"] == "Starbucks":
        new_marker.add_to(starbucks_group)
    elif row["group"] == "Schools":
        new_marker.add_to(schools_group)
    elif row["group"] == "Clubs":
        new_marker.add_to(clubs_group)
    else:
        new_marker.add_to(airports_group)

# Now we add the groups to the maps
pet_group.add_to(office_nearby)
vegan_group.add_to(office_nearby)
basket_group.add_to(office_nearby)
starbucks_group.add_to(office_nearby)
schools_group.add_to(office_nearby)
airports_group.add_to(office_nearby)
clubs_group.add_to(office_nearby)


# Add the office
add_marker("Office Location","red","computer",office_location,office_nearby)

# Add the llayer control
folium.LayerControl(collapsed=False, position="topleft").add_to(office_nearby)
office_nearby
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_844c519696dd96937f02e057a374eae5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_844c519696dd96937f02e057a374eae5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_844c519696dd96937f02e057a374eae5 = L.map(
#                 &quot;map_844c519696dd96937f02e057a374eae5&quot;,
#                 {
#                     center: [51.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11.4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9cc0b3a40937f9421d052150e7131b7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_844c519696dd96937f02e057a374eae5);
#
#
#             var feature_group_d3db28d69b3d1778e9fbc7ce5638d3b8 = L.featureGroup(
#                 {}
#             ).addTo(map_844c519696dd96937f02e057a374eae5);
#
#
#             var marker_e18456524a2623f3aafe8258f2538d2f = L.marker(
#                 [51.51828, -0.124584],
#                 {}
#             ).addTo(feature_group_d3db28d69b3d1778e9fbc7ce5638d3b8);
#
#
#             var icon_62c42313d31cbf1a48860095219cc25b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e18456524a2623f3aafe8258f2538d2f.setIcon(icon_62c42313d31cbf1a48860095219cc25b);
#
#
#             marker_e18456524a2623f3aafe8258f2538d2f.bindTooltip(
#                 `&lt;div&gt;
#                      BOW WOW London Dog Grooming
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_96bc5ce3a99d1fbed6806579c315d020 = L.marker(
#                 [51.500761, -0.132576],
#                 {}
#             ).addTo(feature_group_d3db28d69b3d1778e9fbc7ce5638d3b8);
#
#
#             var icon_78ec4b47182087410d47c049359ba74b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_96bc5ce3a99d1fbed6806579c315d020.setIcon(icon_78ec4b47182087410d47c049359ba74b);
#
#
#             marker_96bc5ce3a99d1fbed6806579c315d020.bindTooltip(
#                 `&lt;div&gt;
#                      Marabese
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7bca9411ae6b2cc135777b4a702dd635 = L.marker(
#                 [51.533094, -0.109435],
#                 {}
#             ).addTo(feature_group_d3db28d69b3d1778e9fbc7ce5638d3b8);
#
#
#             var icon_1b72591dd5c1b1099da0e1e18b733079 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;dog&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7bca9411ae6b2cc135777b4a702dd635.setIcon(icon_1b72591dd5c1b1099da0e1e18b733079);
#
#
#             marker_7bca9411ae6b2cc135777b4a702dd635.bindTooltip(
#                 `&lt;div&gt;
#                      Love Your Pets Grooming &amp; Boutique
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var feature_group_97b93f6cbb4dbdef13c7d9f16934e62f = L.featureGroup(
#                 {}
#             ).addTo(map_844c519696dd96937f02e057a374eae5);
#
#
#             var marker_fa96119efa621e3210a3b8e34417d331 = L.marker(
#                 [51.512617, -0.1207],
#                 {}
#             ).addTo(feature_group_97b93f6cbb4dbdef13c7d9f16934e62f);
#
#
#             var icon_0d7da0a60d6ed51c697aa1aedc2b5eda = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;leaf&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgreen&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fa96119efa621e3210a3b8e34417d331.setIcon(icon_0d7da0a60d6ed51c697aa1aedc2b5eda);
#
#
#             marker_fa96119efa621e3210a3b8e34417d331.bindTooltip(
#                 `&lt;div&gt;
#                      Sagar
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9edfb9aaf0609a9066aebd42d345a5d9 = L.marker(
#                 [51.514349, -0.121845],
#                 {}
#             ).addTo(feature_group_97b93f6cbb4dbdef13c7d9f16934e62f);
